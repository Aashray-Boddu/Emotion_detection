# %% [markdown]
# ## Emotion Detection

# %% [markdown]
# **Importing Libraries**

# %%
## import os
## os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
import os
os.environ["OMP_NUM_THREADS"] = "1"  # restrict to one thread, adjust as needed
os.environ["KMP_BLOCKTIME"] = "30"
os.environ["KMP_SETTINGS"] = "1"
os.environ["KMP_AFFINITY"] = "granularity=fine,compact,1,0"
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
import matplotlib.pyplot as plt
from glob import glob
import cv2
import random
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from IPython.display import SVG, Image
import tensorflow as tf
print("Tensorflow Version:", tf.__version__)
# Out:
# Tensorflow Version: 2.10.0

# %% [markdown]
# **Exploring Dataset**

# %%
images = glob("train/**/**")
for i in range(9):
    image = random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));plt.axis('off')

# %% [markdown]
# **Preparing Data For Training**

# %%
img_size = 48
batch_size = 64
datagen_train = ImageDataGenerator()
train_generator = datagen_train.flow_from_directory("train/", 
                                                    target_size = (img_size,img_size),
                                                    color_mode = "grayscale",
                                                    batch_size = batch_size,
                                                    class_mode = "categorical",
                                                    shuffle = True)
datagen_validation = ImageDataGenerator()
validation_generator= datagen_train.flow_from_directory("test/", 
                                                    target_size = (img_size,img_size),
                                                    color_mode = "grayscale",
                                                    batch_size = batch_size,
                                                    class_mode = "categorical",
                                                    shuffle = True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# **Defining Model**

# %%
def Convolution(input_tensor, filters, kernel_size):
    x = Conv2D(filters = filters, kernel_size = kernel_size, padding = "same")(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size = (2,2))(x)
    x = Dropout(0.25)(x)

    return x

# %%
def Dense_f(input_tensor, nodes):
    x = Dense(nodes)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.25)(x)

    return x

# %%
def model_fer(input_shape):
    inputs = Input(input_shape)
    conv_1 = Convolution(inputs,32,(3,3))
    conv_2 = Convolution(conv_1,64,(5,5))
    conv_3 = Convolution(conv_2,128,(3,3))

    flatten = Flatten()(conv_3)

    dense_1 = Dense_f(flatten,256)

    output = Dense(7,activation = "softmax")(dense_1)
    model = Model(inputs = [inputs], outputs = [output])
    
    model.compile(loss = ['categorical_crossentropy'], optimizer = 'adam', metrics = ['accuracy'])

    return model

# %%
model = model_fer((48,48,1))
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_3 (Conv2D)           (None, 48, 48, 32)        320
#
#  batch_normalization_4 (Batc  (None, 48, 48, 32)       128
#  hNormalization)
#
#  activation_4 (Activation)   (None, 48, 48, 32)        0
#
#  max_pooling2d_3 (MaxPooling  (None, 24, 24, 32)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 24, 24, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 64)        51264
#
#  batch_normalization_5 (Batc  (None, 24, 24, 64)       256
#  hNormalization)
#
#  activation_5 (Activation)   (None, 24, 24, 64)        0
#
#  max_pooling2d_4 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 12, 12, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 128)       73856
#
#  batch_normalization_6 (Batc  (None, 12, 12, 128)      512
#  hNormalization)
#
#  activation_6 (Activation)   (None, 12, 12, 128)       0
#
#  max_pooling2d_5 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_6 (Dropout)         (None, 6, 6, 128)         0
#
#  flatten_1 (Flatten)         (None, 4608)              0
#
#  dense_2 (Dense)             (None, 256)               1179904
#
#  batch_normalization_7 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_7 (Activation)   (None, 256)               0
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 1,309,063
# Trainable params: 1,308,103
# Non-trainable params: 960
# _________________________________________________________________

# %% [markdown]
# **Initializing the Model**

# %%
epochs = 15
steps_per_epoch = train_generator.n//train_generator.batch_size
validation_steps = validation_generator.n//validation_generator.batch_size

checkpoint = ModelCheckpoint("model_weights.h5", monitor = 'val_accuracy', save_weights_only = True, mode = 'max', verbose = 1)
callbacks = [checkpoint]

# %% [markdown]
# # Training the Model

# %% [markdown]
# **The next cell takes time to complete**

# %%
history = model.fit(
    x = train_generator,
    steps_per_epoch = steps_per_epoch,
    epochs = epochs,
    validation_data = validation_generator,
    validation_steps = validation_steps,
    callbacks = callbacks)
# Out:
# Epoch 1/15
# 448/448 [==============================] - ETA: 0s - loss: 1.6924 - accuracy: 0.3582
# Epoch 1: saving model to model_weights.h5
# 448/448 [==============================] - 406s 904ms/step - loss: 1.6924 - accuracy: 0.3582 - val_loss: 1.4797 - val_accuracy: 0.4332
# Epoch 2/15
# 448/448 [==============================] - ETA: 0s - loss: 1.4117 - accuracy: 0.4608
# Epoch 2: saving model to model_weights.h5
# 448/448 [==============================] - 100s 224ms/step - loss: 1.4117 - accuracy: 0.4608 - val_loss: 1.4153 - val_accuracy: 0.4573
# Epoch 3/15
# 448/448 [==============================] - ETA: 0s - loss: 1.2882 - accuracy: 0.5106
# Epoch 3: saving model to model_weights.h5
# 448/448 [==============================] - 97s 216ms/step - loss: 1.2882 - accuracy: 0.5106 - val_loss: 1.2504 - val_accuracy: 0.5170
# Epoch 4/15
# 448/448 [==============================] - ETA: 0s - loss: 1.2052 - accuracy: 0.5445
# Epoch 4: saving model to model_weights.h5
# 448/448 [==============================] - 97s 215ms/step - loss: 1.2052 - accuracy: 0.5445 - val_loss: 1.3823 - val_accuracy: 0.4750
# Epoch 5/15
# 448/448 [==============================] - ETA: 0s - loss: 1.1559 - accuracy: 0.5632
# Epoch 5: saving model to model_weights.h5
# 448/448 [==============================] - 97s 217ms/step - loss: 1.1559 - accuracy: 0.5632 - val_loss: 1.1802 - val_accuracy: 0.5506
# Epoch 6/15
# 448/448 [==============================] - ETA: 0s - loss: 1.1034 - accuracy: 0.5851
# Epoch 6: saving model to model_weights.h5
# 448/448 [==============================] - 97s 217ms/step - loss: 1.1034 - accuracy: 0.5851 - val_loss: 1.2057 - val_accuracy: 0.5391
# Epoch 7/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0571 - accuracy: 0.6031
# Epoch 7: saving model to model_weights.h5
# 448/448 [==============================] - 97s 217ms/step - loss: 1.0571 - accuracy: 0.6031 - val_loss: 1.2100 - val_accuracy: 0.5407
# Epoch 8/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0170 - accuracy: 0.6166
# Epoch 8: saving model to model_weights.h5
# 448/448 [==============================] - 97s 216ms/step - loss: 1.0170 - accuracy: 0.6166 - val_loss: 1.1252 - val_accuracy: 0.5811
# Epoch 9/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9812 - accuracy: 0.6330
# Epoch 9: saving model to model_weights.h5
# 448/448 [==============================] - 194s 434ms/step - loss: 0.9812 - accuracy: 0.6330 - val_loss: 1.2546 - val_accuracy: 0.5427
# Epoch 10/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9427 - accuracy: 0.6473
# Epoch 10: saving model to model_weights.h5
# 448/448 [==============================] - 241s 538ms/step - loss: 0.9427 - accuracy: 0.6473 - val_loss: 1.1423 - val_accuracy: 0.5829
# Epoch 11/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9002 - accuracy: 0.6651
# Epoch 11: saving model to model_weights.h5
# 448/448 [==============================] - 102s 227ms/step - loss: 0.9002 - accuracy: 0.6651 - val_loss: 1.1357 - val_accuracy: 0.5845
# Epoch 12/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8593 - accuracy: 0.6798
# Epoch 12: saving model to model_weights.h5
# 448/448 [==============================] - 101s 226ms/step - loss: 0.8593 - accuracy: 0.6798 - val_loss: 1.1095 - val_accuracy: 0.5972
# Epoch 13/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8288 - accuracy: 0.6937
# Epoch 13: saving model to model_weights.h5
# 448/448 [==============================] - 100s 223ms/step - loss: 0.8288 - accuracy: 0.6937 - val_loss: 1.2292 - val_accuracy: 0.5568
# Epoch 14/15
# 448/448 [==============================] - ETA: 0s - loss: 0.7856 - accuracy: 0.7082
# Epoch 14: saving model to model_weights.h5
# 448/448 [==============================] - 100s 223ms/step - loss: 0.7856 - accuracy: 0.7082 - val_loss: 1.1869 - val_accuracy: 0.5717
# Epoch 15/15
# 448/448 [==============================] - ETA: 0s - loss: 0.7509 - accuracy: 0.7220
# Epoch 15: saving model to model_weights.h5
# 448/448 [==============================] - 104s 231ms/step - loss: 0.7509 - accuracy: 0.7220 - val_loss: 1.1073 - val_accuracy: 0.5999

# %% [markdown]
# **Model Evaluation**

# %%
model.evaluate(validation_generator)
# Out:
# 113/113 [==============================] - 8s 68ms/step - loss: 1.1070 - accuracy: 0.6000
# [1.1069543361663818, 0.600027859210968]

# %% [markdown]
# **Plotting Loss**

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right=0.95,left=0.0,hspace=0.25,wspace=0.35)

# %% [markdown]
# **Plotting Model Accuracy**

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right=0.95,left=0.0,hspace=0.25,wspace=0.35)

# %% [markdown]
# **Saving Model**

# %%
model_json = model.to_json()
with open("model_a.json","w") as json_file:
    json_file.write(model_json)
